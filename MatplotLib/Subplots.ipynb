# %% [markdown]
# # Subplots

# %%
import matplotlib.pyplot as plt

x=[1,2,3,4,5]
x1=["a",'b','c','d','e']
y=[1,2,3,4,5]
y1=[10,15,20,25,30]
plt.subplot(2,2,1)
plt.plot(x,y,color="r")
plt.subplot(2,2,4)
plt.pie([1], colors="y")
plt.subplot(2,2,3)
plt.pie(x)
plt.subplot(2,2,2)
plt.bar(x1,y1)

plt.show()
