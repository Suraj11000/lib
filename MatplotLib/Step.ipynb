# %% [markdown]
# # Step:

# %%
import matplotlib.pyplot as plt

x = [1,2,3,4,5]
y=[4,2,5,4,5]

plt.step(x,y,marker="o",color="r",ms=10,mfc="y",label="Step Plot")
plt.title("Step")
plt.xlabel("X-axis")
plt.ylabel("Y-Axis")
plt.grid()
plt.legend()
plt.show()
