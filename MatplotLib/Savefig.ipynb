# %% [markdown]
# # Savefig:

# %%
import matplotlib.pyplot as plt

x=[1,2,3,4,5]
y=[3,2,5,4,5]

plt.plot(x,y,color="r")

plt.title("Savefig")
plt.xlabel("X-Axis")
plt.ylabel("Y-Axis")

plt.savefig("box_inches",dpi=2000,facecolor="g",transparent=True,bbox_inches="tight")

plt.show()
