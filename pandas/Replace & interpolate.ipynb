# %% [markdown]
# # Replace:

# %%
import pandas as pd
df = pd.read_csv("C:\\Users\\shind\\Desktop\\pandas\\max.csv")
df
# Out:
#     Index          User Id First Name  Last Name     Sex
# 0       1  88F7B33d2bcf9f5     Shelby    Terrell    Male  \
# 1       2  f90cD3E76f1A9b9    Phillip    Summers  Female
# 2       3  DbeAb8CcdfeFC2c   Kristine     Travis    Male
# 3       4  A31Bee3c201ef58    Yesenia   Martinez    Male
# 4       5  1bA7A3dc874da3c       Lori       Todd    Male
# ..    ...              ...        ...        ...     ...
# 95     96  5eFda7caAeB260E     Dennis     Barnes  Female
# 96     97  CCbFce93d3720bE      Steve  Patterson  Female
# 97     98  2fEc528aFAF0b69     Wesley       Bray    Male
# 98     99  Adc7ad9B6e4A1Fe     Summer   Oconnell  Female
# 99    100  b8D0aD3490FC7e1     Mariah    Bernard    Male
#
#                          Email                   Phone Date of birth
# 0         elijah57@example.net  001-084-906-7849x73518    10/26/1945  \
# 1        bethany14@example.com       214.112.6044x4913     3/24/1910
# 2        bthompson@example.com            277.609.7938      7/2/1992
# ...

# %%
# Out:
#              Index
# count  10000.00000
# mean    5000.50000
# std     2886.89568
# min        1.00000
# 25%     2500.75000
# 50%     5000.50000
# 75%     7500.25000
# max    10000.00000

# %%
df.replace(to_replace="Shelby",value="Suraj")
# Out:
#     Index          User Id First Name  Last Name     Sex
# 0       1  88F7B33d2bcf9f5      Suraj    Terrell    Male  \
# 1       2  f90cD3E76f1A9b9    Phillip    Summers  Female
# 2       3  DbeAb8CcdfeFC2c   Kristine     Travis    Male
# 3       4  A31Bee3c201ef58    Yesenia   Martinez    Male
# 4       5  1bA7A3dc874da3c       Lori       Todd    Male
# ..    ...              ...        ...        ...     ...
# 95     96  5eFda7caAeB260E     Dennis     Barnes  Female
# 96     97  CCbFce93d3720bE      Steve  Patterson  Female
# 97     98  2fEc528aFAF0b69     Wesley       Bray    Male
# 98     99  Adc7ad9B6e4A1Fe     Summer   Oconnell  Female
# 99    100  b8D0aD3490FC7e1     Mariah    Bernard    Male
#
#                          Email                   Phone Date of birth
# 0         elijah57@example.net  001-084-906-7849x73518    10/26/1945  \
# 1        bethany14@example.com       214.112.6044x4913     3/24/1910
# 2        bthompson@example.com            277.609.7938      7/2/1992
# ...

# %%
df.replace([1,2,3],51)
# Out:
#     Index          User Id First Name  Last Name     Sex
# 0      51  88F7B33d2bcf9f5     Shelby    Terrell    Male  \
# 1      51  f90cD3E76f1A9b9    Phillip    Summers  Female
# 2      51  DbeAb8CcdfeFC2c   Kristine     Travis    Male
# 3       4  A31Bee3c201ef58    Yesenia   Martinez    Male
# 4       5  1bA7A3dc874da3c       Lori       Todd    Male
# ..    ...              ...        ...        ...     ...
# 95     96  5eFda7caAeB260E     Dennis     Barnes  Female
# 96     97  CCbFce93d3720bE      Steve  Patterson  Female
# 97     98  2fEc528aFAF0b69     Wesley       Bray    Male
# 98     99  Adc7ad9B6e4A1Fe     Summer   Oconnell  Female
# 99    100  b8D0aD3490FC7e1     Mariah    Bernard    Male
#
#                          Email                   Phone Date of birth
# 0         elijah57@example.net  001-084-906-7849x73518    10/26/1945  \
# 1        bethany14@example.com       214.112.6044x4913     3/24/1910
# 2        bthompson@example.com            277.609.7938      7/2/1992
# ...

# %%
df.replace("[A-Za-z]","Suraj",regex=True)
# Out:
#     Index                                            User Id
# 0       1        88Suraj7Suraj33Suraj2SurajSurajSuraj9Suraj5  \
# 1       2        Suraj90SurajSuraj3Suraj76Suraj1Suraj9Suraj9
# 2       3  SurajSurajSurajSurajSuraj8SurajSurajSurajSuraj...
# 3       4        Suraj31SurajSurajSuraj3Suraj201SurajSuraj58
# 4       5    1SurajSuraj7Suraj3SurajSuraj874SurajSuraj3Suraj
# ..    ...                                                ...
# 95     96  5SurajSurajSurajSuraj7SurajSurajSurajSurajSura...
# 96     97  SurajSurajSurajSurajSurajSuraj93Suraj3720Suraj...
# 97     98    2SurajSurajSuraj528SurajSurajSurajSuraj0Suraj69
# 98     99  SurajSurajSuraj7SurajSuraj9Suraj6Suraj4Suraj1S...
# 99    100        Suraj8Suraj0SurajSuraj3490SurajSuraj7Suraj1
#
#                                   First Name
# 0             SurajSurajSurajSurajSurajSuraj  \
# 1        SurajSurajSurajSurajSurajSurajSuraj
# 2   SurajSurajSurajSurajSurajSurajSurajSuraj
# 3        SurajSurajSurajSurajSurajSurajSuraj
# ...

# %%
df.replace({"Sex":"[A-Z]"},51,regex=True)
# Out:
#     Index          User Id First Name  Last Name  Sex
# 0       1  88F7B33d2bcf9f5     Shelby    Terrell   51  \
# 1       2  f90cD3E76f1A9b9    Phillip    Summers   51
# 2       3  DbeAb8CcdfeFC2c   Kristine     Travis   51
# 3       4  A31Bee3c201ef58    Yesenia   Martinez   51
# 4       5  1bA7A3dc874da3c       Lori       Todd   51
# ..    ...              ...        ...        ...  ...
# 95     96  5eFda7caAeB260E     Dennis     Barnes   51
# 96     97  CCbFce93d3720bE      Steve  Patterson   51
# 97     98  2fEc528aFAF0b69     Wesley       Bray   51
# 98     99  Adc7ad9B6e4A1Fe     Summer   Oconnell   51
# 99    100  b8D0aD3490FC7e1     Mariah    Bernard   51
#
#                          Email                   Phone Date of birth
# 0         elijah57@example.net  001-084-906-7849x73518    10/26/1945  \
# 1        bethany14@example.com       214.112.6044x4913     3/24/1910
# 2        bthompson@example.com            277.609.7938      7/2/1992
# ...

# %%
df.replace("Male",method="ffill")
# Out:
#     Index          User Id First Name  Last Name     Sex
# 0       1  88F7B33d2bcf9f5     Shelby    Terrell    Male  \
# 1       2  f90cD3E76f1A9b9    Phillip    Summers  Female
# 2       3  DbeAb8CcdfeFC2c   Kristine     Travis  Female
# 3       4  A31Bee3c201ef58    Yesenia   Martinez  Female
# 4       5  1bA7A3dc874da3c       Lori       Todd  Female
# ..    ...              ...        ...        ...     ...
# 95     96  5eFda7caAeB260E     Dennis     Barnes  Female
# 96     97  CCbFce93d3720bE      Steve  Patterson  Female
# 97     98  2fEc528aFAF0b69     Wesley       Bray  Female
# 98     99  Adc7ad9B6e4A1Fe     Summer   Oconnell  Female
# 99    100  b8D0aD3490FC7e1     Mariah    Bernard  Female
#
#                          Email                   Phone Date of birth
# 0         elijah57@example.net  001-084-906-7849x73518    10/26/1945  \
# 1        bethany14@example.com       214.112.6044x4913     3/24/1910
# 2        bthompson@example.com            277.609.7938      7/2/1992
# ...

# %%
df.replace("Male",method="bfill")
# Out:
#     Index          User Id First Name  Last Name     Sex
# 0       1  88F7B33d2bcf9f5     Shelby    Terrell  Female  \
# 1       2  f90cD3E76f1A9b9    Phillip    Summers  Female
# 2       3  DbeAb8CcdfeFC2c   Kristine     Travis  Female
# 3       4  A31Bee3c201ef58    Yesenia   Martinez  Female
# 4       5  1bA7A3dc874da3c       Lori       Todd  Female
# ..    ...              ...        ...        ...     ...
# 95     96  5eFda7caAeB260E     Dennis     Barnes  Female
# 96     97  CCbFce93d3720bE      Steve  Patterson  Female
# 97     98  2fEc528aFAF0b69     Wesley       Bray  Female
# 98     99  Adc7ad9B6e4A1Fe     Summer   Oconnell  Female
# 99    100  b8D0aD3490FC7e1     Mariah    Bernard    Male
#
#                          Email                   Phone Date of birth
# 0         elijah57@example.net  001-084-906-7849x73518    10/26/1945  \
# 1        bethany14@example.com       214.112.6044x4913     3/24/1910
# 2        bthompson@example.com            277.609.7938      7/2/1992
# ...

# %%
df.replace(1,method="ffill",limit=2)
# Out:
#     Index          User Id First Name  Last Name     Sex
# 0       1  88F7B33d2bcf9f5     Shelby    Terrell    Male  \
# 1       2  f90cD3E76f1A9b9    Phillip    Summers  Female
# 2       3  DbeAb8CcdfeFC2c   Kristine     Travis    Male
# 3       4  A31Bee3c201ef58    Yesenia   Martinez    Male
# 4       5  1bA7A3dc874da3c       Lori       Todd    Male
# ..    ...              ...        ...        ...     ...
# 95     96  5eFda7caAeB260E     Dennis     Barnes  Female
# 96     97  CCbFce93d3720bE      Steve  Patterson  Female
# 97     98  2fEc528aFAF0b69     Wesley       Bray    Male
# 98     99  Adc7ad9B6e4A1Fe     Summer   Oconnell  Female
# 99    100  b8D0aD3490FC7e1     Mariah    Bernard    Male
#
#                          Email                   Phone Date of birth
# 0         elijah57@example.net  001-084-906-7849x73518    10/26/1945  \
# 1        bethany14@example.com       214.112.6044x4913     3/24/1910
# 2        bthompson@example.com            277.609.7938      7/2/1992
# ...

# %%
df.replace(1,method="ffill",limit=3,inplace=True)
df
# Out:
#     Index          User Id First Name  Last Name     Sex
# 0       1  88F7B33d2bcf9f5     Shelby    Terrell    Male  \
# 1       2  f90cD3E76f1A9b9    Phillip    Summers  Female
# 2       3  DbeAb8CcdfeFC2c   Kristine     Travis    Male
# 3       4  A31Bee3c201ef58    Yesenia   Martinez    Male
# 4       5  1bA7A3dc874da3c       Lori       Todd    Male
# ..    ...              ...        ...        ...     ...
# 95     96  5eFda7caAeB260E     Dennis     Barnes  Female
# 96     97  CCbFce93d3720bE      Steve  Patterson  Female
# 97     98  2fEc528aFAF0b69     Wesley       Bray    Male
# 98     99  Adc7ad9B6e4A1Fe     Summer   Oconnell  Female
# 99    100  b8D0aD3490FC7e1     Mariah    Bernard    Male
#
#                          Email                   Phone Date of birth
# 0         elijah57@example.net  001-084-906-7849x73518    10/26/1945  \
# 1        bethany14@example.com       214.112.6044x4913     3/24/1910
# 2        bthompson@example.com            277.609.7938      7/2/1992
# ...

# %% [markdown]
# # Interpolate:

# %%
df = pd.read_csv("C:\\Users\\shind\\Desktop\\pandas\\book.csv")
df
# Out:
#     Index          User Id First Name Last Name     Sex
# 0     1.0  88F7B33d2bcf9f5     Shelby   Terrell    Male  \
# 1     NaN  f90cD3E76f1A9b9    Phillip   Summers  Female
# 2     NaN  DbeAb8CcdfeFC2c        NaN    Travis    Male
# 3     4.0  A31Bee3c201ef58    Yesenia  Martinez    Male
# 4     5.0  1bA7A3dc874da3c       Lori      Todd    Male
# 5     6.0  bfDD7CDEF5D865B       Erin       Day    Male
# 6     NaN  bE9EEf34cB72AF7  Katherine      Buck  Female
# 7     8.0  2EFC6A4e77FaEaC    Ricardo    Hinton    Male
# 8     9.0  baDcC4DeefD8dEB       Dave   Farrell    Male
# 9    10.0  8e4FB470FE19bF0     Isaiah     Downs    Male
# 10   11.0              NaN        NaN       NaN     NaN
# 11    NaN              NaN        NaN       NaN     NaN
# 12   12.0  88F7B33d2bcf9f5     Shelby   Terrell    Male
# 13   14.0  f90cD3E76f1A9b9    Phillip   Summers  Female
# 14    NaN  DbeAb8CcdfeFC2c   Kristine    Travis    Male
# 15   16.0  A31Bee3c201ef58    Yesenia  Martinez    Male
# ...

# %%
df.interpolate()
# Out:
#     Index          User Id First Name Last Name     Sex
# 0     1.0  88F7B33d2bcf9f5     Shelby   Terrell    Male  \
# 1     2.0  f90cD3E76f1A9b9    Phillip   Summers  Female
# 2     3.0  DbeAb8CcdfeFC2c        NaN    Travis    Male
# 3     4.0  A31Bee3c201ef58    Yesenia  Martinez    Male
# 4     5.0  1bA7A3dc874da3c       Lori      Todd    Male
# 5     6.0  bfDD7CDEF5D865B       Erin       Day    Male
# 6     7.0  bE9EEf34cB72AF7  Katherine      Buck  Female
# 7     8.0  2EFC6A4e77FaEaC    Ricardo    Hinton    Male
# 8     9.0  baDcC4DeefD8dEB       Dave   Farrell    Male
# 9    10.0  8e4FB470FE19bF0     Isaiah     Downs    Male
# 10   11.0              NaN        NaN       NaN     NaN
# 11   11.5              NaN        NaN       NaN     NaN
# 12   12.0  88F7B33d2bcf9f5     Shelby   Terrell    Male
# 13   14.0  f90cD3E76f1A9b9    Phillip   Summers  Female
# 14   15.0  DbeAb8CcdfeFC2c   Kristine    Travis    Male
# 15   16.0  A31Bee3c201ef58    Yesenia  Martinez    Male
# ...

# %%
df.interpolate("linear")
# Out:
#     Index          User Id First Name Last Name     Sex
# 0     1.0  88F7B33d2bcf9f5     Shelby   Terrell    Male  \
# 1     2.0  f90cD3E76f1A9b9    Phillip   Summers  Female
# 2     3.0  DbeAb8CcdfeFC2c        NaN    Travis    Male
# 3     4.0  A31Bee3c201ef58    Yesenia  Martinez    Male
# 4     5.0  1bA7A3dc874da3c       Lori      Todd    Male
# 5     6.0  bfDD7CDEF5D865B       Erin       Day    Male
# 6     7.0  bE9EEf34cB72AF7  Katherine      Buck  Female
# 7     8.0  2EFC6A4e77FaEaC    Ricardo    Hinton    Male
# 8     9.0  baDcC4DeefD8dEB       Dave   Farrell    Male
# 9    10.0  8e4FB470FE19bF0     Isaiah     Downs    Male
# 10   11.0              NaN        NaN       NaN     NaN
# 11   11.5              NaN        NaN       NaN     NaN
# 12   12.0  88F7B33d2bcf9f5     Shelby   Terrell    Male
# 13   14.0  f90cD3E76f1A9b9    Phillip   Summers  Female
# 14   15.0  DbeAb8CcdfeFC2c   Kristine    Travis    Male
# 15   16.0  A31Bee3c201ef58    Yesenia  Martinez    Male
# ...

# %%
df.interpolate(method="linear",axis=0)
# Out:
#     Index          User Id First Name Last Name     Sex
# 0     1.0  88F7B33d2bcf9f5     Shelby   Terrell    Male  \
# 1     2.0  f90cD3E76f1A9b9    Phillip   Summers  Female
# 2     3.0  DbeAb8CcdfeFC2c        NaN    Travis    Male
# 3     4.0  A31Bee3c201ef58    Yesenia  Martinez    Male
# 4     5.0  1bA7A3dc874da3c       Lori      Todd    Male
# 5     6.0  bfDD7CDEF5D865B       Erin       Day    Male
# 6     7.0  bE9EEf34cB72AF7  Katherine      Buck  Female
# 7     8.0  2EFC6A4e77FaEaC    Ricardo    Hinton    Male
# 8     9.0  baDcC4DeefD8dEB       Dave   Farrell    Male
# 9    10.0  8e4FB470FE19bF0     Isaiah     Downs    Male
# 10   11.0              NaN        NaN       NaN     NaN
# 11   11.5              NaN        NaN       NaN     NaN
# 12   12.0  88F7B33d2bcf9f5     Shelby   Terrell    Male
# 13   14.0  f90cD3E76f1A9b9    Phillip   Summers  Female
# 14   15.0  DbeAb8CcdfeFC2c   Kristine    Travis    Male
# 15   16.0  A31Bee3c201ef58    Yesenia  Martinez    Male
# ...

# %%
df.interpolate(limit=2)
# Out:
#     Index          User Id First Name Last Name     Sex
# 0     1.0  88F7B33d2bcf9f5     Shelby   Terrell    Male  \
# 1     2.0  f90cD3E76f1A9b9    Phillip   Summers  Female
# 2     3.0  DbeAb8CcdfeFC2c        NaN    Travis    Male
# 3     4.0  A31Bee3c201ef58    Yesenia  Martinez    Male
# 4     5.0  1bA7A3dc874da3c       Lori      Todd    Male
# 5     6.0  bfDD7CDEF5D865B       Erin       Day    Male
# 6     7.0  bE9EEf34cB72AF7  Katherine      Buck  Female
# 7     8.0  2EFC6A4e77FaEaC    Ricardo    Hinton    Male
# 8     9.0  baDcC4DeefD8dEB       Dave   Farrell    Male
# 9    10.0  8e4FB470FE19bF0     Isaiah     Downs    Male
# 10   11.0              NaN        NaN       NaN     NaN
# 11   11.5              NaN        NaN       NaN     NaN
# 12   12.0  88F7B33d2bcf9f5     Shelby   Terrell    Male
# 13   14.0  f90cD3E76f1A9b9    Phillip   Summers  Female
# 14   15.0  DbeAb8CcdfeFC2c   Kristine    Travis    Male
# 15   16.0  A31Bee3c201ef58    Yesenia  Martinez    Male
# ...

# %%
df.interpolate(limit_direction="forward",limit=2)
# Out:
#     Index          User Id First Name Last Name     Sex
# 0     1.0  88F7B33d2bcf9f5     Shelby   Terrell    Male  \
# 1     2.0  f90cD3E76f1A9b9    Phillip   Summers  Female
# 2     3.0  DbeAb8CcdfeFC2c        NaN    Travis    Male
# 3     4.0  A31Bee3c201ef58    Yesenia  Martinez    Male
# 4     5.0  1bA7A3dc874da3c       Lori      Todd    Male
# 5     6.0  bfDD7CDEF5D865B       Erin       Day    Male
# 6     7.0  bE9EEf34cB72AF7  Katherine      Buck  Female
# 7     8.0  2EFC6A4e77FaEaC    Ricardo    Hinton    Male
# 8     9.0  baDcC4DeefD8dEB       Dave   Farrell    Male
# 9    10.0  8e4FB470FE19bF0     Isaiah     Downs    Male
# 10   11.0              NaN        NaN       NaN     NaN
# 11   11.5              NaN        NaN       NaN     NaN
# 12   12.0  88F7B33d2bcf9f5     Shelby   Terrell    Male
# 13   14.0  f90cD3E76f1A9b9    Phillip   Summers  Female
# 14   15.0  DbeAb8CcdfeFC2c   Kristine    Travis    Male
# 15   16.0  A31Bee3c201ef58    Yesenia  Martinez    Male
# ...

# %%
df.interpolate(limit_direction="backward",limit=2)
# Out:
#     Index          User Id First Name Last Name     Sex
# 0     1.0  88F7B33d2bcf9f5     Shelby   Terrell    Male  \
# 1     2.0  f90cD3E76f1A9b9    Phillip   Summers  Female
# 2     3.0  DbeAb8CcdfeFC2c        NaN    Travis    Male
# 3     4.0  A31Bee3c201ef58    Yesenia  Martinez    Male
# 4     5.0  1bA7A3dc874da3c       Lori      Todd    Male
# 5     6.0  bfDD7CDEF5D865B       Erin       Day    Male
# 6     7.0  bE9EEf34cB72AF7  Katherine      Buck  Female
# 7     8.0  2EFC6A4e77FaEaC    Ricardo    Hinton    Male
# 8     9.0  baDcC4DeefD8dEB       Dave   Farrell    Male
# 9    10.0  8e4FB470FE19bF0     Isaiah     Downs    Male
# 10   11.0              NaN        NaN       NaN     NaN
# 11   11.5              NaN        NaN       NaN     NaN
# 12   12.0  88F7B33d2bcf9f5     Shelby   Terrell    Male
# 13   14.0  f90cD3E76f1A9b9    Phillip   Summers  Female
# 14   15.0  DbeAb8CcdfeFC2c   Kristine    Travis    Male
# 15   16.0  A31Bee3c201ef58    Yesenia  Martinez    Male
# ...

# %%
df.interpolate(limit_direction="both",limit=2)
# Out:
#     Index          User Id First Name Last Name     Sex
# 0     1.0  88F7B33d2bcf9f5     Shelby   Terrell    Male  \
# 1     2.0  f90cD3E76f1A9b9    Phillip   Summers  Female
# 2     3.0  DbeAb8CcdfeFC2c        NaN    Travis    Male
# 3     4.0  A31Bee3c201ef58    Yesenia  Martinez    Male
# 4     5.0  1bA7A3dc874da3c       Lori      Todd    Male
# 5     6.0  bfDD7CDEF5D865B       Erin       Day    Male
# 6     7.0  bE9EEf34cB72AF7  Katherine      Buck  Female
# 7     8.0  2EFC6A4e77FaEaC    Ricardo    Hinton    Male
# 8     9.0  baDcC4DeefD8dEB       Dave   Farrell    Male
# 9    10.0  8e4FB470FE19bF0     Isaiah     Downs    Male
# 10   11.0              NaN        NaN       NaN     NaN
# 11   11.5              NaN        NaN       NaN     NaN
# 12   12.0  88F7B33d2bcf9f5     Shelby   Terrell    Male
# 13   14.0  f90cD3E76f1A9b9    Phillip   Summers  Female
# 14   15.0  DbeAb8CcdfeFC2c   Kristine    Travis    Male
# 15   16.0  A31Bee3c201ef58    Yesenia  Martinez    Male
# ...

# %%
df.interpolate(limit_area="inside")
# Out:
#     Index          User Id First Name Last Name     Sex
# 0     1.0  88F7B33d2bcf9f5     Shelby   Terrell    Male  \
# 1     2.0  f90cD3E76f1A9b9    Phillip   Summers  Female
# 2     3.0  DbeAb8CcdfeFC2c        NaN    Travis    Male
# 3     4.0  A31Bee3c201ef58    Yesenia  Martinez    Male
# 4     5.0  1bA7A3dc874da3c       Lori      Todd    Male
# 5     6.0  bfDD7CDEF5D865B       Erin       Day    Male
# 6     7.0  bE9EEf34cB72AF7  Katherine      Buck  Female
# 7     8.0  2EFC6A4e77FaEaC    Ricardo    Hinton    Male
# 8     9.0  baDcC4DeefD8dEB       Dave   Farrell    Male
# 9    10.0  8e4FB470FE19bF0     Isaiah     Downs    Male
# 10   11.0              NaN        NaN       NaN     NaN
# 11   11.5              NaN        NaN       NaN     NaN
# 12   12.0  88F7B33d2bcf9f5     Shelby   Terrell    Male
# 13   14.0  f90cD3E76f1A9b9    Phillip   Summers  Female
# 14   15.0  DbeAb8CcdfeFC2c   Kristine    Travis    Male
# 15   16.0  A31Bee3c201ef58    Yesenia  Martinez    Male
# ...

# %%
df.interpolate(limit_area="outside")
# Out:
#     Index          User Id First Name Last Name     Sex
# 0     1.0  88F7B33d2bcf9f5     Shelby   Terrell    Male  \
# 1     NaN  f90cD3E76f1A9b9    Phillip   Summers  Female
# 2     NaN  DbeAb8CcdfeFC2c        NaN    Travis    Male
# 3     4.0  A31Bee3c201ef58    Yesenia  Martinez    Male
# 4     5.0  1bA7A3dc874da3c       Lori      Todd    Male
# 5     6.0  bfDD7CDEF5D865B       Erin       Day    Male
# 6     NaN  bE9EEf34cB72AF7  Katherine      Buck  Female
# 7     8.0  2EFC6A4e77FaEaC    Ricardo    Hinton    Male
# 8     9.0  baDcC4DeefD8dEB       Dave   Farrell    Male
# 9    10.0  8e4FB470FE19bF0     Isaiah     Downs    Male
# 10   11.0              NaN        NaN       NaN     NaN
# 11    NaN              NaN        NaN       NaN     NaN
# 12   12.0  88F7B33d2bcf9f5     Shelby   Terrell    Male
# 13   14.0  f90cD3E76f1A9b9    Phillip   Summers  Female
# 14    NaN  DbeAb8CcdfeFC2c   Kristine    Travis    Male
# 15   16.0  A31Bee3c201ef58    Yesenia  Martinez    Male
# ...

# %%
 df.interpolate(limit_direction="both",limit=2,inplace=True)
df
# Out:
#     Index          User Id First Name Last Name     Sex
# 0     1.0  88F7B33d2bcf9f5     Shelby   Terrell    Male  \
# 1     2.0  f90cD3E76f1A9b9    Phillip   Summers  Female
# 2     3.0  DbeAb8CcdfeFC2c        NaN    Travis    Male
# 3     4.0  A31Bee3c201ef58    Yesenia  Martinez    Male
# 4     5.0  1bA7A3dc874da3c       Lori      Todd    Male
# 5     6.0  bfDD7CDEF5D865B       Erin       Day    Male
# 6     7.0  bE9EEf34cB72AF7  Katherine      Buck  Female
# 7     8.0  2EFC6A4e77FaEaC    Ricardo    Hinton    Male
# 8     9.0  baDcC4DeefD8dEB       Dave   Farrell    Male
# 9    10.0  8e4FB470FE19bF0     Isaiah     Downs    Male
# 10   11.0              NaN        NaN       NaN     NaN
# 11   11.5              NaN        NaN       NaN     NaN
# 12   12.0  88F7B33d2bcf9f5     Shelby   Terrell    Male
# 13   14.0  f90cD3E76f1A9b9    Phillip   Summers  Female
# 14   15.0  DbeAb8CcdfeFC2c   Kristine    Travis    Male
# 15   16.0  A31Bee3c201ef58    Yesenia  Martinez    Male
# ...
